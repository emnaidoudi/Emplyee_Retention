# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('whitegrid')

# %%
df = pd.read_csv("HR_comma_sep.csv")

# %%
from sklearn.utils import shuffle
df = shuffle(df)

# %%
df.head(2)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 3072                 0.15             0.85               3
# 11947                0.85             0.90               3
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 3072                    199                   2              0     0
# 11947                   245                   3              0     0
#
#        promotion_last_5years      sales  salary
# 3072                       0      sales  medium
# 11947                      0  marketing  medium

# %%
df.shape

# %%
df.describe().T

# %%
df.describe(include="O")

# %%
df.sales.unique()

# %%
df.salary.unique()

# %% [markdown]
# # Data Visualization

# %%
df.corr()

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(), annot=True, cmap="YlGnBu", vmin=-1)

# %%
sns.distplot(df['left'],hist=False, bins=10);

# %%
 ax = sns.countplot(x="left", data=df, palette="Set3")

# %%
 ax = sns.countplot(x="left", data=df[df.sales=="accounting"], palette="Set3")

# %%
ax = sns.boxplot(x=df["satisfaction_level"])

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'sales', 'salary'],
#       dtype='object')

# %%
sums = df.left.groupby(df.sales).sum()

# %%
plt.axis('equal');
plt.pie(sums, labels=sums.index);

# %%
len(df[(df.sales=="IT")&(df.left==1)])
# Out:
# 273

# %%
# Getting the count of people that leave and not
leftcounts=df['left'].value_counts()
print(leftcounts)
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %%
# Using matplotlib pie chart and label the pie chart
plt.pie(leftcounts,labels=['not leave','leave']);

# %%
plt.figure(figsize=(15,8))
sns.factorplot(x="sales",data=df,col="salary",kind="count",aspect=.8,size=14)
